# %%
df.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
df.sample(frac=0.07).to_csv("data/imdb_reviews_sample.csv", index = False)

# %%
# Out:
# array(['10', '100', '15', '20', '30', '50', '80', '90', 'ability', 'able',
#        'absolutely', 'accent', 'act', 'acted', 'acting', 'action',
#        'actor', 'actors', 'actress', 'actual', 'actually', 'add', 'added',
#        'admit', 'adult', 'adventure', 'age', 'ago', 'agree', 'air',
#        'alien', 'alive', 'amazing', 'america', 'american', 'amusing',
#        'animation', 'annoying', 'anti', 'apart', 'apparently', 'appear',
#        'appears', 'appreciate', 'aren', 'army', 'art', 'aside', 'ask',
#        'atmosphere', 'attempt', 'attempts', 'attention', 'audience',
#        'audiences', 'average', 'avoid', 'away', 'awesome', 'awful',
#        'baby', 'background', 'bad', 'badly', 'band', 'barely', 'based',
#        'basic', 'basically', 'battle', 'beautiful', 'beauty', 'begin',
#        'beginning', 'begins', 'believable', 'believe', 'ben', 'best',
#        'better', 'big', 'biggest', 'bit', 'bizarre', 'black', 'blood',
# ...

# %%
# Out:
# Training accuracy: 0.8706
# Test accuracy: 0.8632
# Confusion matrix:
# [[6417 1083]
#  [ 969 6531]]

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# positive    25000
# negative    25000
# Name: count, dtype: int64

# %%
sum(df["sentiment"].isna())
    # no null value!
    # perfection
# Out:
# 0

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc = WordCloud()
first_reviews = df["review"].str.cat()

cloud_first_reviews = wc.generate(first_reviews)
plt.imshow(cloud_first_reviews, interpolation = "bilinear")
plt.axis("off")

plt.show()

# %%
from wordcloud import WordCloud
help(WordCloud)
# Out:
# Help on class WordCloud in module wordcloud.wordcloud:
#
# class WordCloud(builtins.object)
#  |  WordCloud(font_path=None, width=400, height=200, margin=2, ranks_only=None, prefer_horizontal=0.9, mask=None, scale=1, color_func=None, max_words=200, min_font_size=4, stopwords=None, random_state=None, background_color='black', max_font_size=None, font_step=1, mode='RGB', relative_scaling='auto', regexp=None, collocations=True, colormap=None, normalize_plurals=True, contour_width=0, contour_color='black', repeat=False, include_numbers=False, min_word_length=0, collocation_threshold=30)
#  |
#  |  Word cloud object for generating and drawing.
#  |
#  |  Parameters
#  |  ----------
#  |  font_path : string
#  |      Font path to the font that will be used (OTF or TTF).
#  |      Defaults to DroidSansMono path on a Linux machine. If you are on
#  |      another OS or don't have this font, you need to adjust this path.
#  |
#  |  width : int (default=400)
#  |      Width of the canvas.
# ...
